# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %% [markdown]
# ## 1.Data overview

# %%
train.head()
# Out:
#                                     COMMENT_ID           AUTHOR  \
# 0  LZQPQhLyRh80UYxNuaDWhIGQYNQ96IuCg-AYWqNPjpU        Julius NM
# 1          z13jhp0bxqncu512g22wvzkasxmvvzjaz04  ElNino Melendez
# 2          z13fwbwp1oujthgqj04chlngpvzmtt3r3dw           GsMega
# 3          z13lfzdo5vmdi1cm123te5uz2mqig1brz04   ferleck ferles
# 4          z12avveb4xqiirsix04chxviiljryduwxg0      BeBe Burkey
#
#                   DATE                                            CONTENT  \
# 0  2013-11-07T06:20:48  Huh, anyway check out this you[tube] channel: ...
# 1  2013-11-09T08:28:43   me shaking my sexy ass on my channel enjoy ^_^ ﻿
# 2  2013-11-10T16:05:38            watch?v=vtaRGgvGtWQ   Check this out .﻿
# 3  2013-11-27T21:39:24                          Subscribe to my channel ﻿
# 4  2013-11-28T16:30:13  and u should.d check my channel and tell me wh...
#
#    CLASS
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
test.head()
# Out:
#    ID                                   COMMENT_ID            AUTHOR  \
# 0   0  LZQPQhLyRh_C2cTtd9MvFRJedxydaVW-2sNg5Diuo4A       adam riyati
# 1   1  LZQPQhLyRh9MSZYnf8djyk0gEF9BHDPYrrK-qCczIY8  Evgeny Murashkin
# 2   2  LZQPQhLyRh9-wNRtlZDM90f1k0BrdVdJyN_YsaSwfxc      Jason Haddad
# 3   3        z122wfnzgt30fhubn04cdn3xfx2mxzngsl40k      Bob Kanowski
# 4   4          z13ttt1jcraqexk2o234ghbgzxymz1zzi04              Cony
#
#                   DATE                                            CONTENT
# 0  2013-11-07T12:37:15  Hey guys check out my new channel and our firs...
# 1  2013-11-08T17:34:21             just for test I have to say murdev.com
# 2  2013-11-26T02:55:11  Hey, check out my new website!! This site is a...
# 3  2013-11-28T12:33:27  i turned it on mute as soon is i came on i jus...
# 4  2013-11-28T16:01:47    You should check my channel for Funny VIDEOS!!﻿

# %%
train.describe(include=['object','integer'])
# Out:
#                                          COMMENT_ID           AUTHOR  \
# count                                          1157             1157
# unique                                         1156             1094
# top     LneaDw26bFvPh9xBHNw1btQoyP60ay_WWthtvXCx37s  Shadrach Grentz
# freq                                              2                5
# mean                                            NaN              NaN
# std                                             NaN              NaN
# min                                             NaN              NaN
# 25%                                             NaN              NaN
# 50%                                             NaN              NaN
# 75%                                             NaN              NaN
# max                                             NaN              NaN
#
#                        DATE                            CONTENT        CLASS
# count                  1019                               1157  1157.000000
# unique                 1019                               1057          NaN
# top     2014-10-24T06:05:07  Check out this video on YouTube:﻿          NaN
# freq                      1                                 52          NaN
# mean                    NaN                                NaN     0.506482
# std                     NaN                                NaN     0.500174
# min                     NaN                                NaN     0.000000
# 25%                     NaN                                NaN     0.000000
# 50%                     NaN                                NaN     1.000000
# 75%                     NaN                                NaN     1.000000
# max                     NaN                                NaN     1.000000

# %%
test.describe(include=['object','integer'])
# Out:
#                 ID                           COMMENT_ID    AUTHOR  \
# count   799.000000                                  799       799
# unique         NaN                                  799       760
# top            NaN  z12tuvbodnn5ipp3o22mxnarfnnrxbq4z04  5000palo
# freq           NaN                                    1         3
# mean    399.000000                                  NaN       NaN
# std     230.795725                                  NaN       NaN
# min       0.000000                                  NaN       NaN
# 25%     199.500000                                  NaN       NaN
# 50%     399.000000                                  NaN       NaN
# 75%     598.500000                                  NaN       NaN
# max     798.000000                                  NaN       NaN
#
#                               DATE                            CONTENT
# count                          692                                799
# unique                         692                                733
# top     2013-10-21T05:47:26.457000  Check out this video on YouTube:﻿
# freq                             1                                 45
# mean                           NaN                                NaN
# std                            NaN                                NaN
# min                            NaN                                NaN
# 25%                            NaN                                NaN
# 50%                            NaN                                NaN
# 75%                            NaN                                NaN
# max                            NaN                                NaN

# %%
fig,ax= plt.subplots(1,2,figsize=(12,6))
sns.countplot(train.CLASS, palette='Set2', ax=ax[0])
ax[0].set_title('CLASS COUNT')
sns.heatmap(train.isnull(),cmap='Oranges',ax=ax[1])
ax[1].set_title('Missing Values')
# Out:
# Text(0.5,1,'Missing Values')

# %%
fig= plt.figure(figsize=(6,6))
sns.heatmap(test.isnull(),cmap='Greens')
plt.title('Missing Values')
# Out:
# Text(0.5,1,'Missing Values')

# %% [markdown]
# #### From above exploration we can say Class is balanced therefore we don't have to worry about imbalanced problem

# %% [markdown]
# #### Both train and test dataset contains missing values. DATE columns in both train and test set must be handle properly

# %% [markdown]
# ## Due to short timeline of competition i used tableau for EDA. Kindly check tableau file

# %% [markdown]
# ## 2.Feature Engineering

# %%
# create column to check whether CONTENT column in dataset contain any Spam words -> spam_word column : 1 -> Yes , 2-> No
def extract(data):
    words=re.compile(r'check out|check me|card|search|dear|check my|buck|gift|check it|check this|dollar|[=+]|sub|channel|adf|instagram|share|follow|https://|[$]|please|money|free|www|facebook|fb|support|like this comment',re.IGNORECASE)
    data['spam_word']=data.CONTENT.str.contains(words)
    return data

# %%
# create column to check whether AUTHOR commented once or more than once -> MULTI_COMMENT : 1-> Yes , 2 -> No
def feature(data):
    data['MULTI_COMMENT'] = data['AUTHOR'] #to initialise multi_comments
    z=0
    for i in range(len(data)):
        for j in range(1,len(data)):
            if(data.iloc[i,1] == data.iloc[j,1]):
                z=z+1
        if(z>1):
            data.ix[i,'MULTI_COMMENT']=1
        else:
            data.ix[i,'MULTI_COMMENT']=0
        z=0
    return data

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### a) Handling Datetime index

# %%
# function to change index to datetime type and create several columns based on year/month of comments
def datetime(data):
    data=data.set_index('DATE')
    data.index=pd.to_datetime(data.index)
    data['year_2013']=data.index.year==2013
    data['year_2014']=data.index.year==2014
    data['year_2015']=data.index.year==2015
    data['mon_1']=data.index.month==1
    data['mon_2']=data.index.month==2
    data['mon_3']=data.index.month==3
    data['mon_4']=data.index.month==4
    data['mon_5']=data.index.month==5
    data['mon_6']=data.index.month==6
    data['mon_7']=data.index.month==7
    data['mon_8']=data.index.month==8
    data['mon_9']=data.index.month==9
    data['mon_10']=data.index.month==10
    data['mon_11']=data.index.month==11
    data['mon_12']=data.index.month==12
    return(data)

# %% [markdown]
# ### b) Cleaning

# %%
# function to clean dataset
def cleaner(data):
    del data['CONTENT']
    del data['COMMENT_ID']
    del data['AUTHOR']
    x=data.columns
    for i in range(0,17):
        data[x[i]]=np.where(data[x[i]]==True,1,0)
    return data

# %%
# Feature engineering
trainset=extract(train)
trainset=feature(trainset)
testset=extract(test)
testset=feature(testset)

# Handling values (filling date time as 0)
trainset.dropna(inplace=True)
testset.fillna(0,inplace=True)

# Handling Datetime 
trainset=datetime(trainset)
trainset_label=trainset['CLASS']
del trainset['CLASS']
testset=datetime(testset)

# Cleaning Dataset
trainset=cleaner(trainset)
del testset['ID']
testset= cleaner(testset)

# %% [markdown]
# ### c) Creating dummies

# %%
# Hot-1-encoding 
trainset=pd.get_dummies(trainset,drop_first=True)
testset=pd.get_dummies(testset,drop_first=True)

# %%
trainset['new'] = trainset['spam_word'] + trainset['MULTI_COMMENT']
trainset['new']=trainset.new.replace({2:1,1:0})
testset['new'] = testset['spam_word'] + testset['MULTI_COMMENT']
testset['new']=testset.new.replace({2:1,1:0})

# %%
trainset.shape, testset.shape
# Out:
# ((1019, 18), (799, 18))

# %%
trainset.columns, testset.columns
# Out:
# (Index(['spam_word', 'MULTI_COMMENT', 'year_2013', 'year_2014', 'year_2015',
#         'mon_1', 'mon_2', 'mon_3', 'mon_4', 'mon_5', 'mon_6', 'mon_7', 'mon_8',
#         'mon_9', 'mon_10', 'mon_11', 'mon_12', 'new'],
#        dtype='object'),
#  Index(['spam_word', 'MULTI_COMMENT', 'year_2013', 'year_2014', 'year_2015',
#         'mon_1', 'mon_2', 'mon_3', 'mon_4', 'mon_5', 'mon_6', 'mon_7', 'mon_8',
#         'mon_9', 'mon_10', 'mon_11', 'mon_12', 'new'],
#        dtype='object'))

# %% [markdown]
# ## 4) Dimension Reduction

# %%
from sklearn.decomposition import PCA
pca= PCA(n_components=8, whiten= False, random_state=187236)
pca.fit_transform(trainset)
# Out:
# array([[-0.57167641,  0.65633903, -0.08592209, ..., -0.53173983,
#         -0.18203083, -0.1518569 ],
#        [-0.57167641,  0.65633903, -0.08592209, ..., -0.53173983,
#         -0.18203083, -0.1518569 ],
#        [-0.57167641,  0.65633903, -0.08592209, ..., -0.53173983,
#         -0.18203083, -0.1518569 ],
#        ...,
#        [-0.08679884,  0.3711578 ,  0.92595232, ..., -0.49832968,
#          0.54441629,  0.17401494],
#        [-0.08679884,  0.3711578 ,  0.92595232, ..., -0.49832968,
#          0.54441629,  0.17401494],
#        [-0.08679884,  0.3711578 ,  0.92595232, ..., -0.49832968,
#          0.54441629,  0.17401494]])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9065270119410276

# %%
pca_df=pd.DataFrame(pca.fit_transform(trainset),index=trainset.index)
pca_df=pca_df.iloc[:,0:2]
pca_df=pd.concat([pca_df,trainset_label],axis=1)
pca_df.columns=['first','second','label']
sns.lmplot(x='first',y='second', hue='label',data=pca_df, fit_reg=False)

# %% [markdown]
# ## Part3: Predictive Modeling

# %% [markdown]
# ### Splittting data into test and train set

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest = train_test_split(trainset, trainset_label, test_size=0.30,
                                             stratify=trainset_label,random_state=218768763)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# %%
def CrossVal(dataX,dataY,mode,cv=10):
    score=cross_val_score(mode,dataX , dataY, cv=cv, scoring='accuracy')
    return(np.mean(score))

# %%
def plotting(true,pred):
    fig,ax=plt.subplots(1,2,figsize=(10,5))
    precision,recall,threshold = precision_recall_curve(true,pred[:,1])
    ax[0].plot(recall,precision,'g--')
    ax[0].set_xlabel('Recall')
    ax[0].set_ylabel('Precision')
    ax[0].set_title("Average Precision Score : {}".format(average_precision_score(true,pred[:,1])))
    fpr,tpr,threshold = roc_curve(true,pred[:,1])
    ax[1].plot(fpr,tpr)
    ax[1].set_title("AUC Score is: {}".format(auc(fpr,tpr)))
    ax[1].plot([0,1],[0,1],'k--')
    ax[1].set_xlabel('False Positive Rate')
    ax[1].set_ylabel('True Positive Rate')

# %% [markdown]
# ### SGD

# %%
sgd=SGDClassifier(tol=1e-15, random_state=98723,loss='log')
score_sgd=CrossVal(Xtrain,Ytrain,sgd)
print("Accuracy is : ",score_sgd)
sgd.fit(Xtrain,Ytrain)
plotting(Ytest,sgd.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,sgd.predict(Xtest)), annot= True, cmap='Oranges')
sgd_f1=f1_score(Ytest,sgd.predict(Xtest))
plt.title('F1 Score = {}'.format(sgd_f1))
# Out:
# Accuracy is :  0.9593114241001566
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ### b) K-Nearest Neighbors

# %%
k=KNeighborsClassifier(algorithm='auto', n_neighbors= 3)
score_k=CrossVal(Xtrain,Ytrain,k)
print("Accuracy is : ",score_k)
k.fit(Xtrain,Ytrain)
plotting(Ytest,k.predict_proba(Xtest))


fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,k.predict(Xtest)), annot= True, cmap='Reds')
k_f1=f1_score(Ytest,k.predict(Xtest))
plt.title('F1 Score = {}'.format(k_f1))
# Out:
# Accuracy is :  0.955105633802817
# Text(0.5,1,'F1 Score = 0.9288389513108615')

# %% [markdown]
# # Logistic

# %%
lr=LogisticRegression(class_weight='balanced', tol=1e-15)
score_lr=CrossVal(Xtrain,Ytrain,lr)
print("Accuracy is : ",score_lr)
lr.fit(Xtrain,Ytrain)
plotting(Ytest,lr.predict_proba(Xtest))


fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,lr.predict(Xtest)), annot= True, cmap='Greens')
lr_f1=f1_score(Ytest,lr.predict(Xtest))
plt.title('F1 Score = {}'.format(lr_f1))
# Out:
# Accuracy is :  0.9621087636932707
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ## decision tree

# %%
dtc=DecisionTreeClassifier()
score_dtc=CrossVal(Xtrain,Ytrain,dtc)
print("Accuracy is : ",score_dtc)
dtc.fit(Xtrain,Ytrain)
plotting(Ytest,dtc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,dtc.predict(Xtest)), annot= True, cmap='Blues')

dtc_f1=f1_score(Ytest,dtc.predict(Xtest))
plt.title('F1 Score = {}'.format(dtc_f1))
# Out:
# Accuracy is :  0.9607394366197184
# Text(0.5,1,'F1 Score = 0.9407407407407408')

# %% [markdown]
# ### e) Support vector machine

# %%
svc=SVC(C=20,probability=True,kernel='rbf',gamma=0.1)
score_svc=CrossVal(Xtrain,Ytrain,svc)
print("Accuracy is : ",score_svc)
svc.fit(Xtrain,Ytrain)
plotting(Ytest,svc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,svc.predict(Xtest)), annot= True, cmap='Greys')
svc_f1=f1_score(Ytest,svc.predict(Xtest))
plt.title('F1 Score = {}'.format(svc_f1))
# Out:
# Accuracy is :  0.9607394366197184
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ### f) Random Forest Classifier

# %%
rf=RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=125796)
score_rf= CrossVal(Xtrain,Ytrain,rf)
print('Accuracy is:',score_rf)
rf.fit(Xtrain,Ytrain)
plotting(Ytest,rf.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,rf.predict(Xtest)), annot= True, cmap='Oranges')

rf_f1=f1_score(Ytest,rf.predict(Xtest))
plt.title('F1 Score = {}'.format(rf_f1))
# Out:
# Accuracy is: 0.9635367762128325
# Text(0.5,1,'F1 Score = 0.9407407407407408')

# %% [markdown]
# ### g) Extra Trees Classifier

# %%
etc=ExtraTreesClassifier(n_estimators=500, n_jobs=-1, random_state=9845)
score_etc= CrossVal(Xtrain,Ytrain,etc)
print('Accuracy is:',score_etc)
etc.fit(Xtrain,Ytrain)
plotting(Ytest,etc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,etc.predict(Xtest)), annot= True, cmap='Greens')

etc_f1=f1_score(Ytest,etc.predict(Xtest))
plt.title('F1 Score = {}'.format(etc_f1))
# Out:
# Accuracy is: 0.9635367762128325
# Text(0.5,1,'F1 Score = 0.9407407407407408')

# %% [markdown]
# ### h) Ada Boost Classifier

# %%
abc=AdaBoostClassifier(sgd,n_estimators=500, random_state=890,algorithm='SAMME.R', learning_rate=0.01)
score_ada= CrossVal(Xtrain,Ytrain,abc)
print('Accuracy is:',score_ada)
abc.fit(Xtrain,Ytrain)
plotting(Ytest,abc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,abc.predict(Xtest)), annot= True, cmap='Reds')

abc_f1=f1_score(Ytest,abc.predict(Xtest))
plt.title('F1 Score = {}'.format(abc_f1))
# Out:
# Accuracy is: 0.9621087636932707
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ### i) Gradient Boosting Classifier

# %%
gbc=GradientBoostingClassifier(n_estimators=500, random_state=987, learning_rate = 0.01)
score_gbc= CrossVal(Xtrain,Ytrain,gbc)
print('Accuracy is:',score_gbc)
gbc.fit(Xtrain,Ytrain)
plotting(Ytest,gbc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,gbc.predict(Xtest)), annot= True, cmap='Blues')

gbc_f1=f1_score(Ytest,gbc.predict(Xtest))
plt.title('F1 Score = {}'.format(gbc_f1))
# Out:
# Accuracy is: 0.9621283255086072
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ### j) Bagging Classifier

# %%
bc=BaggingClassifier(lr,max_samples=31, bootstrap=True, n_jobs= -1, )
score_bc= CrossVal(Xtrain,Ytrain,gbc)
print('Accuracy is:',score_bc)
bc.fit(Xtrain,Ytrain)
plotting(Ytest,bc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,bc.predict(Xtest)), annot= True, cmap='Greys')

bc_f1=f1_score(Ytest,bc.predict(Xtest))
plt.title('F1 Score = {}'.format(bc_f1))
# Out:
# Accuracy is: 0.9621283255086072
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %% [markdown]
# ### Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier
vc=VotingClassifier(voting='soft', estimators=[('bg',bc),('abc',abc),('svm',svc)])
score_vc= CrossVal(Xtrain,Ytrain,vc)
print('Accuracy is:',score_vc)
vc.fit(Xtrain,Ytrain)
plotting(Ytest,vc.predict_proba(Xtest))

fig=plt.figure()
sns.heatmap(confusion_matrix(Ytest,vc.predict(Xtest)), annot= True, cmap='Greys')

vc_f1=f1_score(Ytest,vc.predict(Xtest))
plt.title('F1 Score = {}'.format(vc_f1))
# Out:
# Accuracy is: 0.959330985915493
# Text(0.5,1,'F1 Score = 0.9442379182156135')

# %%
import lightgbm as lgb

# %%
param = {'bagging_fraction': 0.7516888665358554,
  'feature_fraction': 0.9553537756833577,
  'lambda_l1': 0.0010944748423031836,
  'lambda_l2': 0.0954432971019934,
  'max_depth': 9,
  'min_data_in_leaf': 18,
  'min_gain_to_split': 0.012314142199287075,
  'num_leaves': 14,
    'metric':'auc',
        'objective':'binary',
        'booster':'gbdt'}

# %%
data_1=lgb.Dataset(Xtrain,Ytrain)
data_2=lgb.Dataset(Xtest,Ytest,reference=data_1)
best=lgb.train(param, train_set=data_1, valid_sets=data_2, num_boost_round=10000, early_stopping_rounds=400)
# Out:
# [1]	valid_0's auc: 0.965086
# Training until validation scores don't improve for 400 rounds.
# [2]	valid_0's auc: 0.965151
# [3]	valid_0's auc: 0.961902
# [4]	valid_0's auc: 0.961902
# [5]	valid_0's auc: 0.961902
# [6]	valid_0's auc: 0.961902
# [7]	valid_0's auc: 0.961902
# [8]	valid_0's auc: 0.961902
# [9]	valid_0's auc: 0.961902
# [10]	valid_0's auc: 0.961902
# [11]	valid_0's auc: 0.961902
# [12]	valid_0's auc: 0.961902
# [13]	valid_0's auc: 0.961902
# [14]	valid_0's auc: 0.961902
# [15]	valid_0's auc: 0.961902
# [16]	valid_0's auc: 0.961902
# [17]	valid_0's auc: 0.961902
# [18]	valid_0's auc: 0.961902
# [19]	valid_0's auc: 0.961902
# [20]	valid_0's auc: 0.961902
# [21]	valid_0's auc: 0.961902
# [22]	valid_0's auc: 0.961902
# [23]	valid_0's auc: 0.961902
# [24]	valid_0's auc: 0.960321
# [25]	valid_0's auc: 0.960321
# [26]	valid_0's auc: 0.960321
# [27]	valid_0's auc: 0.962227
# [28]	valid_0's auc: 0.963483
# [29]	valid_0's auc: 0.963483
# [30]	valid_0's auc: 0.963808
# [31]	valid_0's auc: 0.963808
# [32]	valid_0's auc: 0.963808
# [33]	valid_0's auc: 0.969266
# [34]	valid_0's auc: 0.969266
# [35]	valid_0's auc: 0.969439
# [36]	valid_0's auc: 0.969591
# [37]	valid_0's auc: 0.97089
# [38]	valid_0's auc: 0.97219
# [39]	valid_0's auc: 0.968421
# [40]	valid_0's auc: 0.971388
# [41]	valid_0's auc: 0.97154
# [42]	valid_0's auc: 0.97167
# [43]	valid_0's auc: 0.968118
# [44]	valid_0's auc: 0.968118
# [45]	valid_0's auc: 0.968724
# [46]	valid_0's auc: 0.97154
# [47]	valid_0's auc: 0.967641
# [48]	valid_0's auc: 0.967945
# [49]	valid_0's auc: 0.966645
# [50]	valid_0's auc: 0.970804
# [51]	valid_0's auc: 0.977734
# [52]	valid_0's auc: 0.977605
# [53]	valid_0's auc: 0.977605
# [54]	valid_0's auc: 0.977734
# [55]	valid_0's auc: 0.977821
# [56]	valid_0's auc: 0.976522
# [57]	valid_0's auc: 0.976522
# [58]	valid_0's auc: 0.969417
# [59]	valid_0's auc: 0.96227
# [60]	valid_0's auc: 0.96227
# [61]	valid_0's auc: 0.96227
# [62]	valid_0's auc: 0.962573
# [63]	valid_0's auc: 0.965129
# [64]	valid_0's auc: 0.961967
# [65]	valid_0's auc: 0.965432
# [66]	valid_0's auc: 0.965432
# [67]	valid_0's auc: 0.97206
# [68]	valid_0's auc: 0.972363
# [69]	valid_0's auc: 0.965432
# [70]	valid_0's auc: 0.965432
# [71]	valid_0's auc: 0.965302
# [72]	valid_0's auc: 0.971843
# [73]	valid_0's auc: 0.972276
# [74]	valid_0's auc: 0.97232
# [75]	valid_0's auc: 0.97232
# [76]	valid_0's auc: 0.972016
# [77]	valid_0's auc: 0.972016
# [78]	valid_0's auc: 0.972016
# [79]	valid_0's auc: 0.972016
# [80]	valid_0's auc: 0.972016
# [81]	valid_0's auc: 0.972016
# [82]	valid_0's auc: 0.97232
# [83]	valid_0's auc: 0.972016
# [84]	valid_0's auc: 0.972016
# [85]	valid_0's auc: 0.972016
# [86]	valid_0's auc: 0.972016
# [87]	valid_0's auc: 0.972016
# [88]	valid_0's auc: 0.972016
# [89]	valid_0's auc: 0.968551
# [90]	valid_0's auc: 0.968551
# [91]	valid_0's auc: 0.968551
# [92]	valid_0's auc: 0.968204
# [93]	valid_0's auc: 0.968031
# [94]	valid_0's auc: 0.968031
# [95]	valid_0's auc: 0.968204
# [96]	valid_0's auc: 0.968204
# [97]	valid_0's auc: 0.968204
# [98]	valid_0's auc: 0.968204
# [99]	valid_0's auc: 0.968204
# [100]	valid_0's auc: 0.968204
# [101]	valid_0's auc: 0.968204
# [102]	valid_0's auc: 0.968204
# [103]	valid_0's auc: 0.968204
# [104]	valid_0's auc: 0.968204
# [105]	valid_0's auc: 0.968204
# [106]	valid_0's auc: 0.968204
# [107]	valid_0's auc: 0.968204
# [108]	valid_0's auc: 0.968204
# [109]	valid_0's auc: 0.968204
# [110]	valid_0's auc: 0.968204
# [111]	valid_0's auc: 0.968204
# [112]	valid_0's auc: 0.968204
# [113]	valid_0's auc: 0.968204
# [114]	valid_0's auc: 0.968204
# [115]	valid_0's auc: 0.968204
# [116]	valid_0's auc: 0.968204
# [117]	valid_0's auc: 0.968204
# [118]	valid_0's auc: 0.968204
# [119]	valid_0's auc: 0.968204
# [120]	valid_0's auc: 0.968204
# [121]	valid_0's auc: 0.968204
# [122]	valid_0's auc: 0.968204
# [123]	valid_0's auc: 0.968204
# [124]	valid_0's auc: 0.968204
# [125]	valid_0's auc: 0.968204
# [126]	valid_0's auc: 0.968204
# [127]	valid_0's auc: 0.968204
# [128]	valid_0's auc: 0.968204
# [129]	valid_0's auc: 0.968204
# [130]	valid_0's auc: 0.968204
# [131]	valid_0's auc: 0.968204
# [132]	valid_0's auc: 0.968204
# [133]	valid_0's auc: 0.968204
# [134]	valid_0's auc: 0.968204
# [135]	valid_0's auc: 0.968204
# [136]	valid_0's auc: 0.968204
# [137]	valid_0's auc: 0.968204
# [138]	valid_0's auc: 0.968204
# [139]	valid_0's auc: 0.968204
# [140]	valid_0's auc: 0.968204
# [141]	valid_0's auc: 0.968204
# [142]	valid_0's auc: 0.968204
# [143]	valid_0's auc: 0.968204
# [144]	valid_0's auc: 0.968204
# [145]	valid_0's auc: 0.968204
# [146]	valid_0's auc: 0.968204
# [147]	valid_0's auc: 0.968204
# [148]	valid_0's auc: 0.968204
# [149]	valid_0's auc: 0.968204
# [150]	valid_0's auc: 0.968204
# [151]	valid_0's auc: 0.968204
# [152]	valid_0's auc: 0.968204
# [153]	valid_0's auc: 0.968204
# [154]	valid_0's auc: 0.968204
# [155]	valid_0's auc: 0.968204
# [156]	valid_0's auc: 0.968204
# [157]	valid_0's auc: 0.968204
# [158]	valid_0's auc: 0.968204
# [159]	valid_0's auc: 0.968204
# [160]	valid_0's auc: 0.968204
# [161]	valid_0's auc: 0.968204
# [162]	valid_0's auc: 0.968204
# [163]	valid_0's auc: 0.968204
# [164]	valid_0's auc: 0.968204
# [165]	valid_0's auc: 0.968204
# [166]	valid_0's auc: 0.968204
# [167]	valid_0's auc: 0.968204
# [168]	valid_0's auc: 0.968204
# [169]	valid_0's auc: 0.968204
# [170]	valid_0's auc: 0.968204
# [171]	valid_0's auc: 0.968204
# [172]	valid_0's auc: 0.968204
# [173]	valid_0's auc: 0.968204
# [174]	valid_0's auc: 0.968204
# [175]	valid_0's auc: 0.968204
# [176]	valid_0's auc: 0.968204
# [177]	valid_0's auc: 0.968204
# [178]	valid_0's auc: 0.968204
# [179]	valid_0's auc: 0.968204
# [180]	valid_0's auc: 0.968204
# [181]	valid_0's auc: 0.968204
# [182]	valid_0's auc: 0.968204
# [183]	valid_0's auc: 0.968204
# [184]	valid_0's auc: 0.968204
# [185]	valid_0's auc: 0.968204
# [186]	valid_0's auc: 0.968204
# [187]	valid_0's auc: 0.968204
# [188]	valid_0's auc: 0.968204
# [189]	valid_0's auc: 0.968204
# [190]	valid_0's auc: 0.968204
# [191]	valid_0's auc: 0.968204
# [192]	valid_0's auc: 0.968204
# [193]	valid_0's auc: 0.968204
# [194]	valid_0's auc: 0.968204
# [195]	valid_0's auc: 0.968204
# [196]	valid_0's auc: 0.968204
# [197]	valid_0's auc: 0.968204
# [198]	valid_0's auc: 0.968204
# [199]	valid_0's auc: 0.968204
# [200]	valid_0's auc: 0.968204
# [201]	valid_0's auc: 0.968204
# [202]	valid_0's auc: 0.968204
# [203]	valid_0's auc: 0.968204
# [204]	valid_0's auc: 0.968204
# [205]	valid_0's auc: 0.968204
# [206]	valid_0's auc: 0.968204
# [207]	valid_0's auc: 0.968204
# [208]	valid_0's auc: 0.968204
# [209]	valid_0's auc: 0.968204
# [210]	valid_0's auc: 0.968204
# [211]	valid_0's auc: 0.968204
# [212]	valid_0's auc: 0.968204
# [213]	valid_0's auc: 0.968204
# [214]	valid_0's auc: 0.968204
# [215]	valid_0's auc: 0.968204
# [216]	valid_0's auc: 0.968204
# [217]	valid_0's auc: 0.968204
# [218]	valid_0's auc: 0.968204
# [219]	valid_0's auc: 0.968204
# [220]	valid_0's auc: 0.968204
# [221]	valid_0's auc: 0.968204
# [222]	valid_0's auc: 0.968204
# [223]	valid_0's auc: 0.968204
# [224]	valid_0's auc: 0.968204
# [225]	valid_0's auc: 0.968204
# [226]	valid_0's auc: 0.968204
# [227]	valid_0's auc: 0.968204
# [228]	valid_0's auc: 0.968204
# [229]	valid_0's auc: 0.968204
# [230]	valid_0's auc: 0.968204
# [231]	valid_0's auc: 0.968204
# [232]	valid_0's auc: 0.968204
# [233]	valid_0's auc: 0.968204
# [234]	valid_0's auc: 0.968204
# [235]	valid_0's auc: 0.968204
# [236]	valid_0's auc: 0.968204
# [237]	valid_0's auc: 0.968204
# [238]	valid_0's auc: 0.968204
# [239]	valid_0's auc: 0.968204
# [240]	valid_0's auc: 0.968204
# [241]	valid_0's auc: 0.968204
# [242]	valid_0's auc: 0.968204
# [243]	valid_0's auc: 0.968204
# [244]	valid_0's auc: 0.968204
# [245]	valid_0's auc: 0.968204
# [246]	valid_0's auc: 0.968204
# [247]	valid_0's auc: 0.968204
# [248]	valid_0's auc: 0.968204
# [249]	valid_0's auc: 0.968204
# [250]	valid_0's auc: 0.968204
# [251]	valid_0's auc: 0.968204
# [252]	valid_0's auc: 0.968204
# [253]	valid_0's auc: 0.968204
# [254]	valid_0's auc: 0.968204
# [255]	valid_0's auc: 0.968204
# [256]	valid_0's auc: 0.968204
# [257]	valid_0's auc: 0.968204
# [258]	valid_0's auc: 0.968204
# [259]	valid_0's auc: 0.968204
# [260]	valid_0's auc: 0.968204
# [261]	valid_0's auc: 0.968204
# [262]	valid_0's auc: 0.968204
# [263]	valid_0's auc: 0.968204
# [264]	valid_0's auc: 0.968204
# [265]	valid_0's auc: 0.968204
# [266]	valid_0's auc: 0.968204
# [267]	valid_0's auc: 0.968204
# [268]	valid_0's auc: 0.968204
# [269]	valid_0's auc: 0.968204
# [270]	valid_0's auc: 0.968204
# [271]	valid_0's auc: 0.968204
# [272]	valid_0's auc: 0.968204
# [273]	valid_0's auc: 0.968204
# [274]	valid_0's auc: 0.968204
# [275]	valid_0's auc: 0.968204
# [276]	valid_0's auc: 0.968204
# [277]	valid_0's auc: 0.968204
# [278]	valid_0's auc: 0.968204
# [279]	valid_0's auc: 0.968204
# [280]	valid_0's auc: 0.968204
# [281]	valid_0's auc: 0.968204
# [282]	valid_0's auc: 0.968204
# [283]	valid_0's auc: 0.968204
# [284]	valid_0's auc: 0.968204
# [285]	valid_0's auc: 0.968204
# [286]	valid_0's auc: 0.968204
# [287]	valid_0's auc: 0.968204
# [288]	valid_0's auc: 0.968204
# [289]	valid_0's auc: 0.968204
# [290]	valid_0's auc: 0.968204
# [291]	valid_0's auc: 0.968204
# [292]	valid_0's auc: 0.968204
# [293]	valid_0's auc: 0.968204
# [294]	valid_0's auc: 0.968204
# [295]	valid_0's auc: 0.968204
# [296]	valid_0's auc: 0.968204
# [297]	valid_0's auc: 0.968204
# [298]	valid_0's auc: 0.968204
# [299]	valid_0's auc: 0.968204
# [300]	valid_0's auc: 0.968204
# [301]	valid_0's auc: 0.968204
# [302]	valid_0's auc: 0.968204
# [303]	valid_0's auc: 0.968204
# [304]	valid_0's auc: 0.968204
# [305]	valid_0's auc: 0.968204
# [306]	valid_0's auc: 0.968204
# [307]	valid_0's auc: 0.968204
# [308]	valid_0's auc: 0.968204
# [309]	valid_0's auc: 0.968204
# [310]	valid_0's auc: 0.968204
# [311]	valid_0's auc: 0.968204
# [312]	valid_0's auc: 0.968204
# [313]	valid_0's auc: 0.968204
# [314]	valid_0's auc: 0.968204
# [315]	valid_0's auc: 0.968204
# [316]	valid_0's auc: 0.968204
# [317]	valid_0's auc: 0.968204
# [318]	valid_0's auc: 0.968204
# [319]	valid_0's auc: 0.968204
# [320]	valid_0's auc: 0.968204
# [321]	valid_0's auc: 0.968204
# [322]	valid_0's auc: 0.968204
# [323]	valid_0's auc: 0.968204
# [324]	valid_0's auc: 0.968204
# [325]	valid_0's auc: 0.968204
# [326]	valid_0's auc: 0.968204
# [327]	valid_0's auc: 0.968204
# [328]	valid_0's auc: 0.968204
# [329]	valid_0's auc: 0.968204
# [330]	valid_0's auc: 0.968204
# [331]	valid_0's auc: 0.968204
# [332]	valid_0's auc: 0.968204
# [333]	valid_0's auc: 0.968204
# [334]	valid_0's auc: 0.968204
# [335]	valid_0's auc: 0.968204
# [336]	valid_0's auc: 0.968204
# [337]	valid_0's auc: 0.968204
# [338]	valid_0's auc: 0.968204
# [339]	valid_0's auc: 0.968204
# [340]	valid_0's auc: 0.968204
# [341]	valid_0's auc: 0.968204
# [342]	valid_0's auc: 0.968204
# [343]	valid_0's auc: 0.968204
# [344]	valid_0's auc: 0.968204
# [345]	valid_0's auc: 0.968204
# [346]	valid_0's auc: 0.968204
# [347]	valid_0's auc: 0.968204
# [348]	valid_0's auc: 0.968204
# [349]	valid_0's auc: 0.968204
# [350]	valid_0's auc: 0.968204
# [351]	valid_0's auc: 0.968204
# [352]	valid_0's auc: 0.968204
# [353]	valid_0's auc: 0.968204
# [354]	valid_0's auc: 0.968204
# [355]	valid_0's auc: 0.968204
# [356]	valid_0's auc: 0.968204
# [357]	valid_0's auc: 0.968204
# [358]	valid_0's auc: 0.968204
# [359]	valid_0's auc: 0.968204
# [360]	valid_0's auc: 0.968204
# [361]	valid_0's auc: 0.968204
# [362]	valid_0's auc: 0.968204
# [363]	valid_0's auc: 0.968204
# [364]	valid_0's auc: 0.968204
# [365]	valid_0's auc: 0.968204
# [366]	valid_0's auc: 0.968204
# [367]	valid_0's auc: 0.968204
# [368]	valid_0's auc: 0.968204
# [369]	valid_0's auc: 0.968204
# [370]	valid_0's auc: 0.968204
# [371]	valid_0's auc: 0.968204
# [372]	valid_0's auc: 0.968204
# [373]	valid_0's auc: 0.968204
# [374]	valid_0's auc: 0.968204
# [375]	valid_0's auc: 0.968204
# [376]	valid_0's auc: 0.968204
# [377]	valid_0's auc: 0.968204
# [378]	valid_0's auc: 0.968204
# [379]	valid_0's auc: 0.968204
# [380]	valid_0's auc: 0.968204
# [381]	valid_0's auc: 0.968204
# [382]	valid_0's auc: 0.968204
# [383]	valid_0's auc: 0.968204
# [384]	valid_0's auc: 0.968204
# [385]	valid_0's auc: 0.968204
# [386]	valid_0's auc: 0.968204
# [387]	valid_0's auc: 0.968204
# [388]	valid_0's auc: 0.968204
# [389]	valid_0's auc: 0.968204
# [390]	valid_0's auc: 0.968204
# [391]	valid_0's auc: 0.968204
# [392]	valid_0's auc: 0.968204
# [393]	valid_0's auc: 0.968204
# [394]	valid_0's auc: 0.968204
# [395]	valid_0's auc: 0.968204
# [396]	valid_0's auc: 0.968204
# [397]	valid_0's auc: 0.968204
# [398]	valid_0's auc: 0.968204
# [399]	valid_0's auc: 0.968204
# [400]	valid_0's auc: 0.968204
# [401]	valid_0's auc: 0.968204
# [402]	valid_0's auc: 0.968204
# [403]	valid_0's auc: 0.968204
# [404]	valid_0's auc: 0.968204
# [405]	valid_0's auc: 0.968204
# [406]	valid_0's auc: 0.968204
# [407]	valid_0's auc: 0.968204
# [408]	valid_0's auc: 0.968204
# [409]	valid_0's auc: 0.968204
# [410]	valid_0's auc: 0.968204
# [411]	valid_0's auc: 0.968204
# [412]	valid_0's auc: 0.968204
# [413]	valid_0's auc: 0.968204
# [414]	valid_0's auc: 0.968204
# [415]	valid_0's auc: 0.968204
# [416]	valid_0's auc: 0.968204
# [417]	valid_0's auc: 0.968204
# [418]	valid_0's auc: 0.968204
# [419]	valid_0's auc: 0.968204
# [420]	valid_0's auc: 0.968204
# [421]	valid_0's auc: 0.968204
# [422]	valid_0's auc: 0.968204
# [423]	valid_0's auc: 0.968204
# [424]	valid_0's auc: 0.968204
# [425]	valid_0's auc: 0.968204
# [426]	valid_0's auc: 0.968204
# [427]	valid_0's auc: 0.968204
# [428]	valid_0's auc: 0.968204
# [429]	valid_0's auc: 0.968204
# [430]	valid_0's auc: 0.968204
# [431]	valid_0's auc: 0.968204
# [432]	valid_0's auc: 0.968204
# [433]	valid_0's auc: 0.968204
# [434]	valid_0's auc: 0.968204
# [435]	valid_0's auc: 0.968204
# [436]	valid_0's auc: 0.968204
# [437]	valid_0's auc: 0.968204
# [438]	valid_0's auc: 0.968204
# [439]	valid_0's auc: 0.968204
# [440]	valid_0's auc: 0.968204
# [441]	valid_0's auc: 0.968204
# [442]	valid_0's auc: 0.968204
# [443]	valid_0's auc: 0.968204
# [444]	valid_0's auc: 0.968204
# [445]	valid_0's auc: 0.968204
# [446]	valid_0's auc: 0.968204
# [447]	valid_0's auc: 0.968204
# [448]	valid_0's auc: 0.968204
# [449]	valid_0's auc: 0.968204
# [450]	valid_0's auc: 0.968204
# [451]	valid_0's auc: 0.968204
# [452]	valid_0's auc: 0.968204
# [453]	valid_0's auc: 0.968204
# [454]	valid_0's auc: 0.968204
# [455]	valid_0's auc: 0.968204
# Early stopping, best iteration is:
# [55]	valid_0's auc: 0.977821

# %%
best.best_score
# Out:
# defaultdict(dict, {'valid_0': {'auc': 0.977821095949751}})

# %%
pd.DataFrame(rf.feature_importances_,index=Xtrain.columns).sort_values(ascending=False, by=0)
# Out:
#                       0
# spam_word      0.803205
# mon_5          0.079331
# MULTI_COMMENT  0.017750
# year_2015      0.017488
# new            0.017381
# mon_8          0.010077
# year_2014      0.008723
# year_2013      0.008362
# mon_2          0.005911
# mon_1          0.005585
# mon_3          0.005512
# mon_11         0.003978
# mon_12         0.003864
# mon_9          0.003835
# mon_4          0.003678
# mon_10         0.002516
# mon_7          0.001520
# mon_6          0.001284

# %% [markdown]
# #### Since ADA Boost performing better than any other ML algo therefore we will use Ada boost classifier to classify testset

# %%
prediction=vc.predict(testset)
output=pd.DataFrame({'ID':range(0,799), 'CLASS':prediction})
output.to_csv('answer_ada.csv',index=False)
